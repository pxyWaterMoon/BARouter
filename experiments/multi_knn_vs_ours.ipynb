# %%
import os
os.chdir("../")
print("Current work path:", os.getcwd())
# Out:
# 当前工作目录： /home/pengxy2024/ICLR2026

# %%
from src.algorithms.main import main
import os
import yaml

def load_config(config_path):
    # Check if the config file exists
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file not found: {config_path}")
    # Load the configuration from the YAML file
    with open(config_path, "r") as file:
        config = yaml.safe_load(file)
    return config

# %%
config = load_config("src/configs/google_knn.yaml")

main(config)
# Out:
# Building system with configuration: {'project_name': 'routerbench_0shot', 'environment': {'type': 'table', 'file_path': 'data/processed/bert-base-uncased/sprout/online_cost_scale_1000.parquet'}, 'agent': {'type': 'google', 'lambda': 0.85, 'rmodel': {'type': 'knn', 'file_path': 'data/processed/bert-base-uncased/sprout/offline_cost_scale_1000.parquet', 'k': 100}, 'cmodel': {'type': 'knn', 'file_path': 'data/processed/bert-base-uncased/sprout/offline_cost_scale_1000.parquet', 'k': 100}, 'embedding_fn': 'sample2given_embedding'}, 'log_dir': 'outputs/log_sprout', 'T': 5309, 'budget': 800}
# 0.85
# The system is constructed successfully!
#
# Starting system run for 5309 rounds...
# 0.85
# The system is constructed successfully!
#
# Starting system run for 5309 rounds...
#  33%|███▎      | 1748/5309 [00:18<00:37, 95.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 config = load_config("src/configs/google_knn.yaml")
# ----> 3 main(config)
#
# File ~/ICLR2026/src/algorithms/main.py:224, in main(config)
#     221 print(f"The system is constructed successfully!\n")
#     223 # Run the system
# --> 224 run_system(config["T"], env, agent, logger)
#     226 print(f"System run completed. Logs saved to {logger_path}")
#     227 logger.save_history()
#
# File ~/ICLR2026/src/algorithms/main.py:18, in run_system(T, env, agent, logger)
#      16 for t in range(T):
#      17     sample = env.get_sample()
# ---> 18     action = agent.take_action(sample)
#      19     if action == "None":
#      20         response = None
#
# File ~/ICLR2026/src/algorithms/routting_algorithms/google.py:29, in GG.take_action(self, sample)
#      27     sample_list.append(sample)
#      28 predict_reward = self.rmodel.predict(sample_list)
# ---> 29 predict_cost = self.cmodel.predict(sample_list)
#      32 weight = predict_reward - self.lam*predict_cost # (K)
#      33 action_index = np.argmax(weight)
#
# File ~/ICLR2026/src/algorithms/predictor/knn.py:75, in KNN.predict(self, sample_list)
#      71 embedding = embedding.reshape(1,-1).astype(np.float64)
#      72 # x = self.knn.predict(embedding)
#      73 # print(f"[DEBUG] x: {x}")
#      74 # return x[0]
# ---> 75 return self.knn.predict(embedding)[0]
#
# File ~/miniconda3/envs/verl/lib/python3.10/site-packages/sklearn/neighbors/_regression.py:246, in KNeighborsRegressor.predict(self, X)
#     244     neigh_dist = None
#     245 else:
# --> 246     neigh_dist, neigh_ind = self.kneighbors(X)
#     248 weights = _get_weights(neigh_dist, self.weights)
#     250 _y = self._y
#
# File ~/miniconda3/envs/verl/lib/python3.10/site-packages/sklearn/neighbors/_base.py:869, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     862 use_pairwise_distances_reductions = (
#     863     self._fit_method == "brute"
#     864     and ArgKmin.is_usable_for(
#     865         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     866     )
#     867 )
#     868 if use_pairwise_distances_reductions:
# --> 869     results = ArgKmin.compute(
#     870         X=X,
#     871         Y=self._fit_X,
#     872         k=n_neighbors,
#     873         metric=self.effective_metric_,
#     874         metric_kwargs=self.effective_metric_params_,
#     875         strategy="auto",
#     876         return_distance=return_distance,
#     877     )
#     879 elif (
#     880     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     881 ):
#     882     results = _kneighbors_from_graph(
#     883         X, n_neighbors=n_neighbors, return_distance=return_distance
#     884     )
#
# File ~/miniconda3/envs/verl/lib/python3.10/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:281, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     200 """Compute the argkmin reduction.
#     201
#     202 Parameters
#    (...)
#     278 returns.
#     279 """
#     280 if X.dtype == Y.dtype == np.float64:
# --> 281     return ArgKmin64.compute(
#     282         X=X,
#     283         Y=Y,
#     284         k=k,
#     285         metric=metric,
#     286         chunk_size=chunk_size,
#     287         metric_kwargs=metric_kwargs,
#     288         strategy=strategy,
#     289         return_distance=return_distance,
#     290     )
#     292 if X.dtype == Y.dtype == np.float32:
#     293     return ArgKmin32.compute(
#     294         X=X,
#     295         Y=Y,
#    (...)
#     301         return_distance=return_distance,
#     302     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:59, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~/miniconda3/envs/verl/lib/python3.10/site-packages/threadpoolctl.py:592, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     589 def __enter__(self):
#     590     return self
# --> 592 def __exit__(self, type, value, traceback):
#     593     self.restore_original_limits()
#     595 @classmethod
#     596 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:
